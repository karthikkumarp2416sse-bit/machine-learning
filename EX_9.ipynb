# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikkumarp2416sse-bit/machine-learning/blob/main/EX_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(0)
X = np.sort(5 * np.random.rand(80, 1), axis=0)
y = np.sin(X).ravel() + np.random.normal(0, 0.5, X.shape[0])

# %%
linear_regressor = LinearRegression()
linear_regressor.fit(X, y)
# Out:
# LinearRegression()

# %%
polynomial_features = PolynomialFeatures(degree=4)
X_poly = polynomial_features.fit_transform(X)
poly_regressor = LinearRegression()
poly_regressor.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
X_test = np.linspace(0, 5, 100).reshape(-1, 1)
y_pred_linear = linear_regressor.predict(X_test)
X_test_poly = polynomial_features.transform(X_test)
y_pred_poly = poly_regressor.predict(X_test_poly)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual data')
plt.plot(X_test, y_pred_linear, color='red', label='Linear Regression')
plt.plot(X_test, y_pred_poly, color='green', label='Polynomial Regression (Degree 4)')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear vs Polynomial Regression')
plt.legend()
plt.grid(True)
plt.show()

# %%
y_train_pred_linear = linear_regressor.predict(X)
y_train_pred_poly = poly_regressor.predict(X_poly)

mse_linear = mean_squared_error(y, y_train_pred_linear)
mse_poly = mean_squared_error(y, y_train_pred_poly)

print(f"Mean Squared Error (Linear Regression): {mse_linear:.2f}")
print(f"Mean Squared Error (Polynomial Regression): {mse_poly:.2f}")
# Out:
# Mean Squared Error (Linear Regression): 0.51
# Mean Squared Error (Polynomial Regression): 0.21
